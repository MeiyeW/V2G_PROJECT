# %%
import pandas as pd
data_name='iteration1_version3_regupregdown120' 
myresult=pd.read_csv('VehiclesCap_V2G_'+data_name+'.csv',header=0)
N = 6# from 10mins to 1 hour
myresult=myresult.groupby(myresult.index // N).sum()/6# from the unit of W to kW
myresult=myresult.rename(columns={'EnergyDemand':'netload','EnergyGeneration':'gen_capacity_veh','Regup':'regup_capacity_veh','Regdown':'regdown_capacity_veh'})
myresult
# Out:
#     netload  gen_capacity_veh  regup_capacity_veh  regdown_capacity_veh
# 0       0.0     327445.424667       -2.425319e-12          14851.549960
# 1       0.0     339026.114522        0.000000e+00           6235.022145
# 2       0.0     334953.258108        0.000000e+00          14962.020268
# 3       0.0          0.000000        0.000000e+00          13942.420624
# 4       0.0     333244.026030        0.000000e+00         334939.247939
# 5    1100.0     289411.976503        0.000000e+00         334133.333333
# 6       0.0          0.000000        0.000000e+00          55141.849933
# 7    2640.0     236645.233022        0.000000e+00         177810.169270
# 8    7340.0     273080.071143        0.000000e+00         276056.960283
# 9    7920.0     232105.504941        0.000000e+00         260704.468282
# 10  12760.0     244154.906073        0.000000e+00         264000.000000
# 11  18640.0     210880.697438        0.000000e+00         263235.526702
# ...

# %%
data_name='iteration3_version3_regupregdown120' 
myresult2=pd.read_csv('VehiclesCap_V2G_'+data_name+'.csv',header=0)
N = 6# from 10mins to 1 hour
myresult2=myresult2.groupby(myresult2.index // N).sum()/6# from the unit of W to kW
myresult2=myresult2.rename(columns={'EnergyDemand':'netload','EnergyGeneration':'gen_capacity_veh','Regup':'regup_capacity_veh','Regdown':'regdown_capacity_veh'})
myresult2
# Out:
#     netload  gen_capacity_veh  regup_capacity_veh  regdown_capacity_veh
# 0       0.0     295558.266667                 0.0           5800.000000
# 1       0.0     295984.015928                 0.0           4384.842538
# 2       0.0     290498.056311                 0.0           6266.666667
# 3       0.0          0.000000                 0.0          13286.556103
# 4       0.0     279172.662656                 0.0         289264.507592
# 5     240.0     255818.036145                 0.0         282780.089381
# 6     480.0          0.000000                 0.0          38073.228972
# 7    3500.0     242509.412195                 0.0         173021.518340
# 8    9820.0     304989.021678                 0.0         265505.886935
# 9   10740.0     300734.796911                 0.0         286600.440925
# 10  10800.0     259801.954804                 0.0         299244.502305
# 11  13580.0     228573.117352                 0.0         294420.000000
# ...

# %%
myresult4
# Out:
#     netload  gen_capacity_veh  regup_capacity_veh  regdown_capacity_veh
# 0       0.0     338884.015928            0.000000           7933.333333
# 1       0.0     342565.179376            0.000000           1577.725578
# 2       0.0     336265.048456            0.000000           6939.468830
# 3       0.0          0.000000            0.000000           6619.622327
# 4       0.0     338607.385505            0.000000         407200.000000
# 5     240.0     302726.866480            0.000000         320323.913480
# 6     480.0          0.000000            0.000000          38617.935300
# 7    6460.0     194887.791781            0.000000         205225.817350
# 8    6620.0     229065.239436         1049.937684         246543.449766
# 9    8400.0     206813.203183            0.000000         211651.144931
# 10  14760.0     186201.287520            0.000000         212348.808995
# 11  17920.0     162123.327458            0.000000         217731.526702
# ...

# %%
difference=myresult-myresult2
difference
# Out:
#     netload  gen_capacity_veh  regup_capacity_veh  regdown_capacity_veh
# 0       0.0      31887.158000       -2.425319e-12           9051.549960
# 1       0.0      43042.098593        0.000000e+00           1850.179608
# 2       0.0      44455.201797        0.000000e+00           8695.353602
# 3       0.0          0.000000        0.000000e+00            655.864521
# 4       0.0      54071.363374        0.000000e+00          45674.740347
# 5     860.0      33593.940357        0.000000e+00          51353.243952
# 6    -480.0          0.000000        0.000000e+00          17068.620961
# 7    -860.0      -5864.179173        0.000000e+00           4788.650930
# 8   -2480.0     -31908.950535        0.000000e+00          10551.073348
# 9   -2820.0     -68629.291970        0.000000e+00         -25895.972643
# 10   1960.0     -15647.048731        0.000000e+00         -35244.502305
# 11   5060.0     -17692.419914        0.000000e+00         -31184.473298
# ...

# %%
data_name='iteration5_version3_regupregdown120' 

myresult3=pd.read_csv('VehiclesCap_V2G_'+data_name+'.csv',header=0)
N = 6# from 10mins to 1 hour
myresult3=myresult3.groupby(myresult3.index // N).sum()/6# from the unit of W to kW
myresult3=myresult3.rename(columns={'EnergyDemand':'netload','EnergyGeneration':'gen_capacity_veh','Regup':'regup_capacity_veh','Regdown':'regdown_capacity_veh'})
myresult3

difference=myresult2-myresult3
difference
# Out:
#          netload  gen_capacity_veh  regup_capacity_veh  regdown_capacity_veh
# 0   0.000000e+00     -76216.666667                 0.0          -4254.568925
# 1   0.000000e+00     -74411.416162                 0.0          -3190.887088
# 2   0.000000e+00     -77261.671283                 0.0          -3066.666667
# 3   0.000000e+00          0.000000                 0.0           2010.802146
# 4   0.000000e+00     -81174.844995                 0.0         -74547.312205
# 5   0.000000e+00     -68218.014626                 0.0         -80353.243952
# 6   0.000000e+00          0.000000                 0.0          -9013.011505
# 7  -2.273737e-12       1740.678965                 0.0         -36834.552907
# 8   3.440000e+03      16156.211928                 0.0         -36927.477805
# 9   2.100000e+03      52031.035474                 0.0           9445.735116
# 10 -2.820000e+03       8075.360961                 0.0          22009.435639
# ...

# %%
data_name='iteration7_version3_regupregdown120' 

myresult4=pd.read_csv('VehiclesCap_V2G_'+data_name+'.csv',header=0)
N = 6# from 10mins to 1 hour
myresult4=myresult4.groupby(myresult4.index // N).sum()/6# from the unit of W to kW
myresult4=myresult4.rename(columns={'EnergyDemand':'netload','EnergyGeneration':'gen_capacity_veh','Regup':'regup_capacity_veh','Regdown':'regdown_capacity_veh'})
myresult4

difference=myresult3-myresult4
difference
# myresult4
# Out:
#     netload  gen_capacity_veh  regup_capacity_veh  regdown_capacity_veh
# 0       0.0      32890.917405            0.000000           2121.235591
# 1       0.0      27830.252714            0.000000           5998.004048
# 2       0.0      31494.679137            0.000000           2393.864503
# 3       0.0          0.000000            0.000000           4656.131631
# 4       0.0      21740.122146            0.000000         -43388.180203
# 5       0.0      21309.184291            0.000000          42809.419854
# 6       0.0          0.000000            0.000000           8468.305177
# 7   -2960.0      45880.941449            0.000000           4630.253898
# 8    -240.0      59767.570314        -1049.937684          55889.914975
# 9     240.0      41890.558253            0.000000          65503.560878
# 10  -1140.0      65525.306323            0.000000          64886.257671
# 11  -2100.0      54380.594274            0.000000          62742.873298
# ...

# %%
data_name='iteration7_version3_regupregdown120' 
myresult2=pd.read_csv('VehiclesCap_V2G_'+data_name+'.csv',header=0)
N = 6# from 10mins to 1 hour
myresult2=myresult2.groupby(myresult2.index // N).sum()/6# from the unit of W to kW
myresult2=myresult2.rename(columns={'EnergyDemand':'netload','EnergyGeneration':'gen_capacity_veh','Regup':'regup_capacity_veh','Regdown':'regdown_capacity_veh'})
myresult2

myresult3=pd.concat([myresult3,myresult2],axis=1)
myresult3
# Out:
#     netload  gen_capacity_veh  regup_capacity_veh  regdown_capacity_veh  \
# 0       0.0     327445.424667       -2.425319e-12          14851.549960
# 1       0.0     339026.114522        0.000000e+00           6235.022145
# 2       0.0     334953.258108        0.000000e+00          14962.020268
# 3       0.0          0.000000        0.000000e+00          13942.420624
# 4       0.0     333244.026030        0.000000e+00         334939.247939
# 5    1100.0     289411.976503        0.000000e+00         334133.333333
# 6       0.0          0.000000        0.000000e+00          55141.849933
# 7    2640.0     236645.233022        0.000000e+00         177810.169270
# 8    7340.0     273080.071143        0.000000e+00         276056.960283
# 9    7920.0     232105.504941        0.000000e+00         260704.468282
# 10  12760.0     244154.906073        0.000000e+00         264000.000000
# 11  18640.0     210880.697438        0.000000e+00         263235.526702
# ...
